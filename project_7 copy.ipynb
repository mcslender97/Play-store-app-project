# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
path=os.path.join(".","googleplaystore.csv")
path
# Out:
# '.\\googleplaystore.csv'

# %%
df = pd.read_csv(path).dropna()

# %%
df
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10834                                      FR Calculator               FAMILY
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
df.head(5)# Check top 5 rows
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews  Size     Installs  Type Price Content Rating  \
# 0     159   19M      10,000+  Free     0       Everyone
# 1     967   14M     500,000+  Free     0       Everyone
# 2   87510  8.7M   5,000,000+  Free     0       Everyone
# 3  215644   25M  50,000,000+  Free     0           Teen
# 4     967  2.8M     100,000+  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# ...

# %%
df.tail(3)# Check last 3 rows
# Out:
#                                                  App             Category  \
# 10837               Fr. Mike Schmitz Audio Teachings               FAMILY
# 10839                  The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840  iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
#        Rating Reviews                Size     Installs  Type Price  \
# 10837     5.0       4                3.6M         100+  Free     0
# 10839     4.5     114  Varies with device       1,000+  Free     0
# 10840     4.5  398307                 19M  10,000,000+  Free     0
#
#       Content Rating             Genres      Last Updated         Current Ver  \
# 10837       Everyone          Education      July 6, 2018                 1.0
# 10839     Mature 17+  Books & Reference  January 19, 2015  Varies with device
# 10840       Everyone          Lifestyle     July 25, 2018  Varies with device
#
#               Android Ver
# 10837          4.1 and up
# 10839  Varies with device
# ...

# %%
df.shape# FInd shape of dataset
# Out:
# (9360, 13)

# %%
# Get genral info
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9360 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             9360 non-null   object
#  1   Category        9360 non-null   object
#  2   Rating          9360 non-null   float64
#  3   Reviews         9360 non-null   object
#  4   Size            9360 non-null   object
#  5   Installs        9360 non-null   object
#  6   Type            9360 non-null   object
#  7   Price           9360 non-null   object
#  8   Content Rating  9360 non-null   object
#  9   Genres          9360 non-null   object
#  10  Last Updated    9360 non-null   object
#  11  Current Ver     9360 non-null   object
#  12  Android Ver     9360 non-null   object
# dtypes: float64(1), object(12)
# memory usage: 1023.8+ KB

# %%
df['Reviews']=df['Reviews'].astype("int32")

# %%
df.loc[df['App'].str.contains('astrology',case=False)]# Get all apps contain Astrology in title
# Out:
#                                                      App   Category  Rating  \
# 1570   Horoscopes – Daily Zodiac Horoscope and Astrology  LIFESTYLE     4.6
# 1592              သိင်္ Astrology - Min Thein Kha BayDin  LIFESTYLE     4.7
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology  LIFESTYLE     4.5
#
#        Reviews Size     Installs  Type Price Content Rating     Genres  \
# 1570    161143  11M  10,000,000+  Free     0   Everyone 10+  Lifestyle
# 1592      2225  15M     100,000+  Free     0       Everyone  Lifestyle
# 10840   398307  19M  10,000,000+  Free     0       Everyone  Lifestyle
#
#         Last Updated         Current Ver         Android Ver
# 1570   June 25, 2018          5.2.4(881)        4.0.3 and up
# 1592   July 26, 2018               4.2.1        4.0.3 and up
# 10840  July 25, 2018  Varies with device  Varies with device

# %%
df.loc[df['App'].str.contains('Astrology',case=True)]
# Out:
#                                                      App   Category  Rating  \
# 1570   Horoscopes – Daily Zodiac Horoscope and Astrology  LIFESTYLE     4.6
# 1592              သိင်္ Astrology - Min Thein Kha BayDin  LIFESTYLE     4.7
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology  LIFESTYLE     4.5
#
#        Reviews Size     Installs  Type Price Content Rating     Genres  \
# 1570    161143  11M  10,000,000+  Free     0   Everyone 10+  Lifestyle
# 1592      2225  15M     100,000+  Free     0       Everyone  Lifestyle
# 10840   398307  19M  10,000,000+  Free     0       Everyone  Lifestyle
#
#         Last Updated         Current Ver         Android Ver
# 1570   June 25, 2018          5.2.4(881)        4.0.3 and up
# 1592   July 26, 2018               4.2.1        4.0.3 and up
# 10840  July 25, 2018  Varies with device  Varies with device

# %%
len(df.loc[df['App'].str.contains('astrology',case=False)])
# Out:
# 3

# %%
df['Rating'].mean()# Get average app rating
# Out:
# 4.191837606837612

# %%
df['Category'].unique()# Get all app category
# Out:
# array(['ART_AND_DESIGN', 'AUTO_AND_VEHICLES', 'BEAUTY',
#        'BOOKS_AND_REFERENCE', 'BUSINESS', 'COMICS', 'COMMUNICATION',
#        'DATING', 'EDUCATION', 'ENTERTAINMENT', 'EVENTS', 'FINANCE',
#        'FOOD_AND_DRINK', 'HEALTH_AND_FITNESS', 'HOUSE_AND_HOME',
#        'LIBRARIES_AND_DEMO', 'LIFESTYLE', 'GAME', 'FAMILY', 'MEDICAL',
#        'SOCIAL', 'SHOPPING', 'PHOTOGRAPHY', 'SPORTS', 'TRAVEL_AND_LOCAL',
#        'TOOLS', 'PERSONALIZATION', 'PRODUCTIVITY', 'PARENTING', 'WEATHER',
#        'VIDEO_PLAYERS', 'NEWS_AND_MAGAZINES', 'MAPS_AND_NAVIGATION'],
#       dtype=object)

# %%
df.groupby('Category')['Rating'].mean().sort_values(ascending=False)# Get average rating of app category, highest to lowest
# Out:
# Category
# EVENTS                 4.435556
# EDUCATION              4.389032
# ART_AND_DESIGN         4.377049
# BOOKS_AND_REFERENCE    4.346067
# PERSONALIZATION        4.335256
# PARENTING              4.300000
# GAME                   4.286326
# BEAUTY                 4.278571
# HEALTH_AND_FITNESS     4.277104
# SHOPPING               4.259664
# SOCIAL                 4.255598
# WEATHER                4.244000
# SPORTS                 4.223511
# PRODUCTIVITY           4.211396
# HOUSE_AND_HOME         4.197368
# FAMILY                 4.192383
# PHOTOGRAPHY            4.192114
# AUTO_AND_VEHICLES      4.190411
# MEDICAL                4.189143
# LIBRARIES_AND_DEMO     4.179688
# FOOD_AND_DRINK         4.166972
# COMMUNICATION          4.158537
# COMICS                 4.155172
# NEWS_AND_MAGAZINES     4.132189
# FINANCE                4.131889
# ENTERTAINMENT          4.126174
# BUSINESS               4.121452
# TRAVEL_AND_LOCAL       4.109292
# LIFESTYLE              4.094904
# ...

# %%
len(df['Category'].unique())# Number of unique categories
# Out:
# 33

# %%
len(df[df['Rating']==5.0])
# Out:
# 274

# %%
# Get average reviews. Column is obj type thus giving inf if caculate mean, thus conversion to float is needed to get number value
df['Reviews'].astype("float").mean()
# Out:
# 514376.7052350427

# %%
df['Type'].unique()
# Out:
# array(['Free', 'Paid'], dtype=object)

# %%
# No of free apps
len(df[df['Type']=='Free'])
# Out:
# 8715

# %%
len(df[df['Type']=='Paid'])# No of paid apps
# Out:
# 645

# %%
df.sort_values(by='Reviews',ascending=False).head(1)# Ap with max amount of reviews
# Out:
#            App Category  Rating   Reviews                Size        Installs  \
# 2544  Facebook   SOCIAL     4.1  78158306  Varies with device  1,000,000,000+
#
#       Type Price Content Rating  Genres    Last Updated         Current Ver  \
# 2544  Free     0           Teen  Social  August 3, 2018  Varies with device
#
#              Android Ver
# 2544  Varies with device

# %%
df.sort_values(by='Reviews',ascending=False).head(5)
# Out:
#                      App       Category  Rating   Reviews                Size  \
# 2544            Facebook         SOCIAL     4.1  78158306  Varies with device
# 3943            Facebook         SOCIAL     4.1  78128208  Varies with device
# 381   WhatsApp Messenger  COMMUNICATION     4.4  69119316  Varies with device
# 336   WhatsApp Messenger  COMMUNICATION     4.4  69119316  Varies with device
# 3904  WhatsApp Messenger  COMMUNICATION     4.4  69109672  Varies with device
#
#             Installs  Type Price Content Rating         Genres  \
# 2544  1,000,000,000+  Free     0           Teen         Social
# 3943  1,000,000,000+  Free     0           Teen         Social
# 381   1,000,000,000+  Free     0       Everyone  Communication
# 336   1,000,000,000+  Free     0       Everyone  Communication
# 3904  1,000,000,000+  Free     0       Everyone  Communication
#
#         Last Updated         Current Ver         Android Ver
# ...

# %%
# average daring of free and paid app
(df[df['Type']=='Free'])['Rating'].mean()
# Out:
# 4.186288009179587

# %%
(df[df['Type']=='Paid'])['Rating'].mean()
# Out:
# 4.266821705426354

# %%
# Top installed apps (there are more than 5 apps)
# Installs are repesented as "over certain number" instead of actual install numbers. Max over range is 1,000,000,000 and there are 58 apps.
df.loc[df['Installs']=='1,000,000,000+']
# Out:
#                                            App             Category  Rating  \
# 152                          Google Play Books  BOOKS_AND_REFERENCE     3.9
# 335   Messenger – Text and Video Chat for Free        COMMUNICATION     4.0
# 336                         WhatsApp Messenger        COMMUNICATION     4.4
# 338               Google Chrome: Fast & Secure        COMMUNICATION     4.3
# 340                                      Gmail        COMMUNICATION     4.3
# 341                                   Hangouts        COMMUNICATION     4.0
# 381                         WhatsApp Messenger        COMMUNICATION     4.4
# 382   Messenger – Text and Video Chat for Free        COMMUNICATION     4.0
# 386                                   Hangouts        COMMUNICATION     4.0
# 391              Skype - free IM & video calls        COMMUNICATION     4.1
# 411               Google Chrome: Fast & Secure        COMMUNICATION     4.3
# ...

# %%
df.iloc[::2,1::2]
# Out:
#                   Category  Reviews    Installs Price  \
# 0           ART_AND_DESIGN      159     10,000+     0
# 2           ART_AND_DESIGN    87510  5,000,000+     0
# 4           ART_AND_DESIGN      967    100,000+     0
# 6           ART_AND_DESIGN      178     50,000+     0
# 8           ART_AND_DESIGN    13791  1,000,000+     0
# ...                    ...      ...         ...   ...
# 10828               COMICS      291     10,000+     0
# 10830   NEWS_AND_MAGAZINES      881    100,000+     0
# 10833  BOOKS_AND_REFERENCE       44      1,000+     0
# 10836               FAMILY       38      5,000+     0
# 10839  BOOKS_AND_REFERENCE      114      1,000+     0
#
#                         Genres         Current Ver
# 0                 Art & Design               1.0.0
# 2                 Art & Design               1.2.4
# 4      Art & Design;Creativity                 1.1
# 6                 Art & Design                 1.1
# 8                 Art & Design               2.9.2
# ...

# %%
# Remove the plus over Install over column
df['Installs over']=df['Installs'].apply(lambda x: x[:-1])
# df['Installs over']=df['Installs'].str[:-1]
# Convert Install over to number, first removing , seperator
df['Installs over']=df['Installs over'].str.replace(",","").astype("int32")
df
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10834                                      FR Calculator               FAMILY
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
df.sort_values(by='Installs over',ascending=False).head(10)
# Out:
#                                            App            Category  Rating  \
# 451                                      Gmail       COMMUNICATION     4.3
# 3665                                   YouTube       VIDEO_PLAYERS     4.3
# 382   Messenger – Text and Video Chat for Free       COMMUNICATION     4.0
# 386                                   Hangouts       COMMUNICATION     4.0
# 391              Skype - free IM & video calls       COMMUNICATION     4.1
# 3687                   Google Play Movies & TV       VIDEO_PLAYERS     3.7
# 411               Google Chrome: Fast & Secure       COMMUNICATION     4.3
# 3736                               Google News  NEWS_AND_MAGAZINES     3.9
# 3765                               Google News  NEWS_AND_MAGAZINES     3.9
# 865                          Google Play Games       ENTERTAINMENT     4.3
#
#        Reviews                Size        Installs  Type Price Content Rating  \
# ...
